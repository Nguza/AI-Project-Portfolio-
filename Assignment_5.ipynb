# %% [markdown]
# <a href="https://colab.research.google.com/github/Nguza/AI-Project-Portfolio-/blob/main/Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Library

# %%
# !pip install transformers torch -q

# %% [markdown]
# Text Generation Pipeline

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

print(f'Succesfully loaded model {model_name}')
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Succesfully loaded model gpt2

# %% [markdown]
# Prompt

# %%
["Write s short furutistic poem about AI:"]

for prompt in prompts:
    print("\n===============================")
    print("PROMPT:", prompt)

    result = generator(prompt, max_length=100, num_return_sequences=2, truncation=True)

    for i, output in enumerate(result):
        print(f"nVariation {i+1}:")
        print(output["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
# PROMPT: Write a short futuristic poem about AI:
# nVariation 1:
# Write a short futuristic poem about AI:
#
# "You're a genius, but you're not smart enough to figure out how to do it. How to think like a human can't, and what to do when it doesn't? It's too simple, too simple. And then it's too complicated to think about how you're going to do it. You're going to get bored. You're going to make more mistakes. And you've got a lot of stuff that you shouldn't have done. This is a very difficult problem to solve. You're not going to be able to do something that you don't want to do."
#
# ...

# %% [markdown]
# Data Cleaning & Tokenization

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

sample_text = "AI is tranforming the future."
tokens = tokenizer.tokenize(sample_text)
token_ids = tokenizer.encode(sample_text)

print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Tokens: ['AI', 'Ġis', 'Ġtr', 'an', 'forming', 'Ġthe', 'Ġfuture', '.']
# Token IDs: [20185, 318, 491, 272, 15464, 262, 2003, 13]

# %% [markdown]
# Visualiztion of Variation

# %%
generator("The Future of AI is", max_length=50, num_return_sequences=2)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
